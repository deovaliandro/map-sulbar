# %%
import geopandas as gpd

# %%
gdf = gpd.read_file("RBI_Desa_10K_2023_Sulawesi_Barat.shp")
gdf = gdf.to_crs(epsg=4326)
gdf.to_file("desa.geojson", driver='GeoJSON', index=False)

print("The shapefile has been converted into GEOJSON file format.")
# Out:
# The shapefile has been converted into GEOJSON file format.
